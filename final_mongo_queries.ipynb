# %%
import pickle
import pandas as pd
import pymongo
from pymongo import TEXT
import numpy as np

myclient = pymongo.MongoClient("mongodb://localhost")
mydb = myclient["yelp"]
business = mydb["business"]
review = mydb["review"]
user = mydb["user"]
# Out:
# /var/folders/qv/8c5mbc9n6757hp9t1hcsx90m0000gn/T/ipykernel_1573/587523463.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import zipfile
import os.path

if not os.path.isfile('yelp_dataset/yelp_academic_dataset_review.json'):
    with zipfile.ZipFile('yelp_dataset/yelp_academic_dataset_review.json', 'r') as zip_ref:
        zip_ref.extractall('data')

if not os.path.isfile('yelp_dataset/yelp_academic_dataset_user.json'):
    with zipfile.ZipFile('yelp_dataset/yelp_academic_dataset_user.json', 'r') as zip_ref:
        zip_ref.extractall('data')

if not os.path.isfile('yelp_dataset/yelp_academic_dataset_business.json'):
    with zipfile.ZipFile('yelp_dataset/yelp_academic_dataset_business.json', 'r') as zip_ref:
        zip_ref.extractall('data')

# %%
import json

if business.count_documents({}) == 0:
    print("Loading business collection...")
    with open('yelp_dataset/yelp_academic_dataset_business.json', encoding='utf-8') as f:
        for line in f:
            business.insert_one(json.loads(line))

if review.count_documents({}) == 0:
    print("Loading review collection...")
    with open('yelp_dataset/yelp_academic_dataset_review.json', encoding='utf-8') as f:
        for line in f:
            review.insert_one(json.loads(line))
            
if user.count_documents({}) == 0:
    print("Loading user collection...")
    with open('yelp_dataset/yelp_academic_dataset_user.json', encoding='utf-8') as f:
        for line in f:
            user.insert_one(json.loads(line))

# %%
pipeline = [
    {
        "$match": { "state": "FL" }
    },
    {
        "$group": {
            "_id": "$city",
            "business_count": { "$sum": 1 }
        }
    },
    {
        "$sort": { "business_count": -1 }
    },
    {
        "$project": {
            "_id": 0,
            "city": "$_id",
            "business_count": 1
        }
    }
]

results = business.aggregate(pipeline)
df = pd.DataFrame(list(results))

print("Cities in FL with the Most Businesses:")
print(df)
# Out:
# Cities in FL with the Most Businesses:
#      business_count                  city
# 0              9048                 Tampa
# 1              2221            Clearwater
# 2              1663      Saint Petersburg
# 3              1185        St. Petersburg
# 4              1033               Brandon
# ..              ...                   ...
# 221               1           spring hill
# 222               1               ​Lithia
# 223               1        TARPON SPRINGS
# 224               1          Apollo beach
# 225               1  Wyndlake Condominium
#
# [226 rows x 2 columns]

# %%
pipeline = [
    {
        "$match": { "state": "FL" }
    },
    {
        "$group": {
            "_id": "$city",
            "business_count": { "$sum": 1 }
        }
    },
    {
        "$sort": { "business_count": -1 }
    },
    {
        "$limit": 3
    },
    {
        "$project": {
            "_id": 0,
            "city": "$_id",
            "business_count": 1
        }
    }
]

results = business.aggregate(pipeline)

df_top_cities = pd.DataFrame(list(results))

print("Top 3 Cities in FL with the Most Businesses:")
print(df_top_cities)
# Out:
# Top 3 Cities in FL with the Most Businesses:
#    business_count              city
# 0            9048             Tampa
# 1            2221        Clearwater
# 2            1663  Saint Petersburg

# %% [markdown]
# TAMPAS BIGGESST HATER QUERY

# %%
business.create_index([("business_id", 1)], name="business_id_idx")
business.create_index([("city", 1)], name="city_idx")
business.create_index([("state", 1)], name="state_idx")

review.create_index([("business_id", 1)], name="review_business_id_idx")
review.create_index([("user_id", 1)], name="review_user_id_idx")

user.create_index([("user_id", 1)], name="user_id_idx")
# Out:
# 'user_id_idx'

# %%
user_ids_to_remove = [
    '5XiPz5mJK_RtJQVkXIqxYg',
    'NCeW1I6C4K7qhY4kRH8cOA',
    'vq2H7lJ73VwXMDqC8DiImw'
]
result = review.delete_many({
    'user_id': {'$in': user_ids_to_remove}
})

#verify
remaining_reviews = review.count_documents({
    'user_id': {'$in': user_ids_to_remove}
})

print(f"Remaining reviews for specified user_ids: {remaining_reviews}")
# Out:
# Remaining reviews for specified user_ids: 0

# %%
pipeline_fl_businesses = [
    {"$match": {"state": "FL"}}
]

fl_businesses = list(business.aggregate(pipeline_fl_businesses))

# %%
import re

city_variations = ["Tampa", "Tampa Bay", "tampa", "TAMPA"]

escaped_cities = [re.escape(city) for city in city_variations]
regex_pattern = f"^({'|'.join(escaped_cities)})$"

pipeline_tampa_businesses = [
    {"$match": {
        "city": {"$regex": regex_pattern, "$options": "i"},
        "state": "FL"
    }}
]

tampa_businesses = list(business.aggregate(pipeline_tampa_businesses))

# %%
tampa_business_ids = [business["business_id"] for business in tampa_businesses]

# %%
pipeline_tampa_reviews = [
    {"$match": {"business_id": {"$in": tampa_business_ids}}}
]

tampa_reviews = list(review.aggregate(pipeline_tampa_reviews))

# %%
pipeline_hater_query = [

    {"$match": {"business_id": {"$in": tampa_business_ids}}},
    # Join with user collection to get user names
    {
        "$lookup": {
            "from": "user",
            "localField": "user_id",
            "foreignField": "user_id",
            "as": "user_details"
        }
    },
    {"$unwind": "$user_details"},
    {
        "$group": {
            "_id": {"user_id": "$user_id", "user_name": "$user_details.name"},
            "review_count": {"$sum": 1},
            "avg_stars": {"$avg": "$stars"}
        }
    },
    {"$match": {"review_count": {"$gt": 5}}},
    # Sort by avg_stars ascending and review_count descending
    {"$sort": { "user_name" : 1,"avg_stars": 1,  "review_count": -1}},
    {"$limit": 10},
    {
        "$project": {
            "_id": 0,
            "user_id": "$_id.user_id",
            "user_name": "$_id.user_name",
            "review_count": 1,
            "avg_stars": {"$round": ["$avg_stars", 2]}
        }
    }
]

hater_query_results = list(review.aggregate(pipeline_hater_query))

df_hater_query = pd.DataFrame(hater_query_results)

print("Top 10 Haters in Tampa, FL:")
print(df_hater_query)
# Out:
# Top 10 Haters in Tampa, FL:
#    review_count                 user_id  user_name  avg_stars
# 0            14  C7fbmhCmXXhtWRZyW6Nzmg          A        1.0
# 1            10  k2lXKvz4iSw0OZSSojCkdw  Bob-A-Lou        1.0
# 2            10  YgeZ-tJ0ZEU_m41pGBng_A     Carlos        1.0
# 3             9  mAI_E0rVjyC4FF9PSn37rA      Terry        1.0
# 4             9  zHKbREByeKvgbKPxbKIweA        Vic        1.0
# 5             9  CGp3KducoS3lemPVanz0Xw       Lola        1.0
# 6             9  OL87RR63x07Y0K2xpCG4Aw     Nicole        1.0
# 7             9  fluPpH9ap58Y5xkPPyFQuQ       Rick        1.0
# 8             9  EXL55TgQAo1RRUIpZvKmWQ      Sandy        1.0
# 9             9  mvUw8RPzmXkVdCR4Pr_WJg      Mauro        1.0

# %%
# explain_cmd = {
#     "explain": {
#         "aggregate": "review",          # The name of the collection
#         "pipeline": pipeline_hater_query,
#         "cursor": {}
#     },
#     "verbosity": "executionStats"        # or "queryPlanner" / "allPlansExecution"
# }

# # Run the explain command
# explain_result = mydb.command(explain_cmd)

# # Print the explain output nicely
# print(json.dumps(explain_result, indent=4))

# %%
mydb.command('explain', {'aggregate': 'review', 'pipeline': pipeline_hater_query, 'cursor': {}}, verbosity='executionStats')
# Out:
# {'explainVersion': '1',
#  'stages': [{'$cursor': {'queryPlanner': {'namespace': 'yelp.review',
#      'parsedQuery': {'business_id': {'$in': ['--ARBQr1WMsTWiwOKOj-FQ',
#         '--LC8cIrALInl2vyo701tg',
#         '--eBbs3HpZYIym5pEw8Qdw',
#         '--gJkxbsiSIwsQKbiwm_Ng',
#         '--pDYWb4DzqKdAdrPcxuaA',
#         '--rS-rnOIZxoiDA8yctWpQ',
#         '-0i2KNr7WrCsDF5m0IViJg',
#         '-0oPt7sSKtJG1ysLwV_E9g',
#         '-1WM2044r3jVZC6oQ2QeVA',
#         '-1oygVebK81K8JEPI6H6Lw',
#         '-2C-Ll8cbgNMpEKokXK6Dw',
#         '-2CPhK6ik9ZBgFX_F-dkxQ',
#         '-2ZIgbTr50xq64ODisvKhw',
#         '-2dvQxx3cYXd5XmFdDDsDA',
#         '-2slH9PUjJ9YK16b0hGxWg',
#         '-2wh7NTLkWEgsrLJvilnFQ',
#         '-34c4hcDPIInTROr8Xtxtw',
#         '-361Hc0tlxSYdrH_C3OgzA',
#         '-3w58iNJL_sZuT0Ozpz0yQ',
#         '-4HTX6yWNuRJusCTezaUnQ',
#         '-53z4kzdbB9F4kPQqmQjyg',
#         '-5fXJjU1oeWnCHW5MPOuxg',
#         '-5iuX3tPbwH5LpoWN9QhMQ',
#         '-5psHqEISccHDdHaWF2-6Q',
#         '-788YqeAedOZseDJOo7kfQ',
#         '-7GjicSH_rM8JeZGCXGcUg',
#         '-7caEbWfsQkV5UGCYAcPDw',
#         '-AMPRbkJZJcyIH_IuEreDg',
#         '-AOtXkmNAMtx-Y2Kx0CiFA',
#         '-AWclhh1_2VnqPylPgBU3g',
#         '-AjSXsdPtBhWl0kY1-QsoA',
#         '-B7m-EJ8Moe6pSqMEqAVEA',
#         '-BB9Xn-ak_23FxVEWI5Y8w',
#         '-BLhAShTxDVYHjmDaAV0Tg',
#         '-Cf1DZ-2BVEjaGJ55U7GYg',
#         '-DXnU-mJlRAz6K-Kmj2sfA',
#         '-EEtnHdSUwHEq_oll_BhFw',
#         '-EGUHD80Yj0_bsBImJCITg',
#         '-EHrU_DwtX2Jv4NbAMppTA',
#         '-EKgs6Dl5Ft2Y0bEhYPZgg',
#         '-EOlTGHfMPiB7GehuuayJw',
#         '-EiVVg6mJMzzr13_j8PNog',
#         '-Em2RqlmPqWJSwUMekKNHA',
#         '-ExvxN1QHx4efMLm6PxJ4A',
#         '-FIYPnxsg3kuHXx46zY18w',
#         '-G2G-h_TjNLXzI5FCbaqQA',
#         '-GJCEanNnPvwW5YggyECow',
#         '-Gx5W9lIcD2UDcwLJ6S0Fg',
#         '-H2P_GjJWy5sFZ5j22HH8w',
#         '-H89PQSv6MGXFvWJBCCeAg',
#         '-HWc5-NQLKBIIlBcDMfKCw',
#         '-HbZLx47yHLdp98kSEog2g',
#         '-IEIG_vEijEESseR_XCZvQ',
#         '-IHmqXaIj9L6gfJUoyAB3w',
#         '-J0RIXNexJDV-mOAyhUJIQ',
#         '-J0tPzkwPnyulSBE_s863Q',
#         '-JcSG0yNk06hpNWagOKj9g',
#         '-JpnQBGy8daXKvMvtjto2w',
#         '-K0LoSCfh8i5U_y53Krepg',
#         '-LA43tgCUKqAX4ws4cIz6g',
#         '-McT2dWG_uKAEkyVqZaUOw',
#         '-N4g2zaKpILmyiUO9qi8IQ',
#         '-O4XZLqMJy9FmX-nVkl1-A',
#         '-ODKTf6sVBn3i-M08NDHlQ',
#         '-OJT4RJ0OPZ8fgCmKH851Q',
#         '-ONBja1I0ePL7-yxCefYSg',
#         '-P4wyB0ncCDoKNpPM3OEkg',
#         '-Qt0Xdu3O9PxQDw4toiViA',
#         '-RB6uWNiV-Ili1mu_tapgQ',
#         '-RQTEz9AaGU4uJB_dCEkmQ',
#         '-RUdfNAuUs-G8m5urhnvvA',
#         '-Rxzg3Iekz9NBXLTehOSEw',
#         '-SCIBOTjKGJXmeMMPi-uoQ',
#         '-SFSt3FkjGfavnyMpHsZPA',
#         '-SrM3yq5yBBnZGn9Gtm7rA',
#         '-Ssuh_iWh-VEcqRLAK-grQ',
#         '-T6z1weFkH1XAmDWU3tgdw',
#         '-UbWaC43ydtM6gK4vjD-uA',
#         '-V4mOW2jGViwiqkavT_2Uw',
#         '-VTvQDLzXrlntLdo-uLqwg',
#         '-VfLXThgY1Qz3ODVwFuEzw',
#         '-WLCdaCEA4JaGAFTK3_shg',
#         '-WQjN0W4CD5sw2DywN11NQ',
#         '-WY6gUBgI5aFsvzqhJgLlg',
#         '-WjTNKDYRyagBFCpHmkqVA',
#         '-X6sw58z7yoFq0UuF9EoNw',
#         '-Y0d5ckFTrjvzxZCQoxhhQ',
#         '-ZCctA2zuUMxUihDwhYXAg',
#         '-ZEYG0EXGXnLMEqOTftMVA',
#         '-_5bIz9bmlMfKkH4CVbUVA',
#         '-_URFnpoO-6C-cbtPoiqpA',
#         '-_VIDwzHvmfyxahHwWvqcQ',
#         '-_arFpHzoPHvh5p-YKw5fQ',
#         '-aXBwEc28UdpcNtl6B6sGA',
#         '-b3VxSmRw1Qot8dtDLdluQ',
#         '-b7A7e2zh3CDTpgChRoRKw',
#         '-bR_RgtKytmFOHGPVUBcWg',
#         '-btcqphKk_d1FPiMRtxswg',
#         '-cP8uNoweeq8K079DrCZMw',
#         '-ch3ET0QStiKPWo1Vy68eA',
#         '-cj-WAPHPJjGrOkuwCaXfQ',
#         '-digbta5SDBePF4raNpl0Q',
#         '-eBDRVn1mPwHFCF_hry20Q',
#         '-eQWM400LZchuoLOuc4x1A',
#         '2GreXhwEXRLc673Mj_Vyjg',
#         '2GsKpssQQIVhSKA3kWfo_g',
#         '2HrDPuB9UyDWpWk7N_0gPQ',
#         '2I2jDIr0kL2bQCtYBfknkg',
#         '2ISbt4jtUSs0c1eYx836HQ',
#         '2IqknEjg4MC6zZ1UdMOwsA',
#         '2Ix7aG_r0mmvO1HBnIL-IA',
#         '2J25ayD4_TMyoBbi-E3WMg',
#         '2JEUOJgPuAGVX9CXTdNRAA',
#         '2Jh3irHzOb6UEo6ZVxwZUA',
#         '2K7MwRA00bN5Sp8sGm_oUw',
#         '2KDhh-PkRmKVyt4N9TkcTA',
#         '2KHS8Vuao5QZhs2YUE3b5g',
#         '2KWkhKme1Ouwc1MH0B91kg',
#         '2KcOPle9TbcvWagez9Az0A',
#         '2LK3DWkmzZRVK6M2YnWECw',
#         '2LL2x12hLrA3lFi3_NQ7sA',
#         '2Lxh3hkp_7j8-OEFDV6nVg',
#         '2Mpja5TqX8uSWPrhkRao6Q',
#         '2NkiRQj3QbeO-5EAyLW0Xg',
#         '2OkaI_XmeGsR9rBcTomjWg',
#         '2PjqWbfEefH1AMpL4opE4A',
#         '2PxQ_sP8aySmSRJAGLDJog',
#         '2QOtxxxjN8fCI1XaKsiuqw',
#         '2QPlFQ4161uWsS-pXyX7JQ',
#         '2SlzqZRAh2g0PUQ0C8PZ8g',
#         '2TK1p6uIO7dHDWOQeit0Fg',
#         '2U3Vn7AdOOb1-tAF0S-tiA',
#         '2UIuLdsEajiThwIsVKV90Q',
#         '2UKQMo-lMi5q0hOoTfaHuw',
#         '2ULbBiF21osgJgDrgWCKzA',
#         '2V82l0NAsTWwOaoDQvSqxw',
#         '2VQk0GTVm5s4g27ZraBSpQ',
#         '2VXsRCKgu54OIUA6882CiA',
#         '2VuOLrhe2Iu_FRz1gEIqQA',
#         '2WvQNYUU9h3ddV3cRLtL2Q',
#         '2XFRm3DSYm6ULx0oPTpQCg',
#         '2Y0XyJCu3JGGLUga-u0RjQ',
#         '2YanqRyvO7nzfwi2SPQa7w',
#         '2YxhKXIGCOTGaCxz_k_iIg',
#         '2ZOxI30m2SSGqjt35RS6xg',
#         '2ZZNXvWrUrkVpplWrFMT0g',
#         '2_dHkH2XpIlvmANwZBvSNg',
#         '2a-iiIvB7CK4VINu-jy9tg',
#         '2aiH-2U0ezVSl9WZjkosXQ',
#         '2ao_W1PVns8TyaGeCocMVQ',
#         '2baniRD5IsrjxHgs55O-8Q',
#         '2bu7Au6Qr2Ediic_3BgvQw',
#         '2bxuJvMum0LtrWIXHVcuQg',
#         '2c7qkJxkNUi8WLp1HlrjQw',
#         '2cnVPyfSYOuQjYDhHYnd1g',
#         '2d2JsoZNuyG7T56F1JLjNw',
#         '2dn_5TYwEuTtt42HYflJeA',
#         '2e84tDIUMclrYDkpGyydqQ',
#         '2eh-YnYDolnY4rzQ3AqeGg',
#         '2fHvRWTYpRp_yljAN3QhtQ',
#         '2f_iPtdEPRS9fVXWPdisEQ',
#         '2gP6_NF9T4rQmcDgFESfBQ',
#         '2gbZHBaYw_kfWmD0CmIVkQ',
#         '2gpurfo0rwpkW0Xp7TGjgg',
#         '2hErWx-q_Ixx6zYgQMPw7g',
#         '2i0QXDm-7UaCkOlhzXWdpg',
#         '2iKrBPw-mXRPPu2EmfxMSQ',
#         '2j43r7yLc-KwJ6JNsKbPUg',
#         '2jK36fVSvBx5p_qjfXd11Q',
#         '2jRrqwGjgHgJ9rn0Ptaxuw',
#         '2jxPMeCFpD1_Kg5Ygd3Zmg',
#         '2kVpK2gaspKFQCVvXUVLOA',
#         '2kuhZOrWcLYe_XePccr4lA',
#         '2lQrzb0WPexs7oPdAPpQFw',
#         '2m26upG2jwaIkIAW1jAO5A',
#         '2mM1TXP0mNSMK2Vt6Ya1rQ',
#         '2nLUfGQNcZ6WiJzGx1xTbQ',
#         '2nNai-XOQGSbn-kAYh6DPw',
#         '2nnp7C4d9QrJ616R39wKUA',
#         '2oJEZAxMIt9dGwap1r6xAg',
#         '2oh4NJDtqTUO5ZuvCe0hWw',
#         '2otpG9OkXE3Ldywjv97S5w',
#         '2pWQjLkIynlvTdgPGxINvQ',
#         '2pWloZENgEOocyU6WtPsnw',
#         '2pXS9GDt2csyLRn6rQkR-w',
#         '2pYUBcNkUxD1Bg8FA5lCzg',
#         '2pwS546BwvNVwYoa1Wf20g',
#         '2s5lNFhwWm_nBl3BFvrjLw',
#         '2sJxkMo5fpCsk4i2T2z-zA',
#         '2tIjb8ZKuRI5tFGgo_izVQ',
#         '2u0VeSqc7f8cLF5BUedvCA',
#         '2u88essZZkL1NIPW0wwOSA',
#         '2uTM_dpF3iTV7-5zyk1_9w',
#         '2uYYreZ90a7oyK7u2_NT8w',
#         '2ukJ2tNmtWfHvpGjYMgVnA',
#         '2vLwBpIqpG5Cci8K-xD8uQ',
#         '2vem8MAsmx8mXtSSIFFrnQ',
#         '2vv-XYwabiTFDkrvB-uOXg',
#         '2wBH7uas5eiUuWgz8c2KIg',
#         '2y4IM4_B30QW3718m98-dA',
#         '2yZjiRGCNBnuc9uM2I1-lw',
#         '2z_dEk3ZllVLJvS-x18dog',
#         '2zeC6SFWDgf7lMFRDqFyiQ',
#         '3-6sf8XfL5Ski1mcVwWpxw',
#         '3-SD1f75MP44KQjzzE35Tg',
#         '309eD1s4UG_TkBNHUKAzYA',
#         '30ICxo9TTeRUFfSSdLc9Bw',
#         '30iNoQB-k7LW_SuLfWDq7g',
#         '30iPzAg-vFWVHmzRt8cs3Q',
#         '30rM6JGz_4cqjeBJZ93thA',
#         '32mDDkHt7xX3Log9l90rnw',
#         '338D7EQfInzHV8Ve1b0-eQ',
#         '33XoAmh6TH77AqQr8NRMhQ',
#         '33_nk27fgNtXw54GH1WeyA',
#         '33vn9DFZHVCPD52eYTPNVw',
#         '33zxFqIOe6Yg8qPXKkhUjg',
#         '34VCZUaNp-sqPkhy_NwK4g',
#         '34zPMn_NYpmxP5poSDF4QQ',
#         '35BuVcbDU7D9mjmruxmnEw',
#         '35xe-xLwaYiA6ZfFvQC29w',
#         '36TrLKi_sifUWD3tMyKwnw',
#         '6-294oU3uO9mE_RKk6O2xg',
#         '6-cxfuwufT4vhxGyjSO8fA',
#         '6-l9lANMQxLG0-ajO7f3tQ',
#         '60lyE0aqFQbjb-NwMnSuFw',
#         '60wupyK0tPqVPeo5Dcl24w',
#         '61E9XINU9W5FWTCKxBzjbQ',
#         '61WfILSR1C9n7jjRnIZehQ',
#         '61s7FRkBoo8BDWJKQNTeCg',
#         '62uvGH1pgrQyC7XHePLEHw',
#         '63M3cXwALoUozKK7ruYqYA',
#         ...]}},
#      'indexFilterSet': False,
#      'queryHash': 'E1724094',
#      'planCacheKey': 'D561F516',
#      'optimizationTimeMillis': 9,
#      'maxIndexedOrSolutionsReached': False,
#      'maxIndexedAndSolutionsReached': False,
#      'maxScansToExplodeReached': False,
#      'prunedSimilarIndexes': False,
#      'winningPlan': {'isCached': False,
#       'stage': 'PROJECTION_SIMPLE',
#       'transformBy': {'stars': 1, 'user_id': 1, '_id': 0},
#       'inputStage': {'stage': 'FETCH',
#        'inputStage': {'stage': 'IXSCAN',
#         'keyPattern': {'business_id': 1},
#         'indexName': 'review_business_id_idx',
#         'isMultiKey': False,
#         'multiKeyPaths': {'business_id': []},
#         'isUnique': False,
#         'isSparse': False,
#         'isPartial': False,
#         'indexVersion': 2,
#         'direction': 'forward',
#         'indexBounds': {'business_id': ['["--ARBQr1WMsTWiwOKOj-FQ", "--ARBQr1WMsTWiwOKOj-FQ"]',
#           '["--LC8cIrALInl2vyo701tg", "--LC8cIrALInl2vyo701tg"]',
#           '["--eBbs3HpZYIym5pEw8Qdw", "--eBbs3HpZYIym5pEw8Qdw"]',
#           '["--gJkxbsiSIwsQKbiwm_Ng", "--gJkxbsiSIwsQKbiwm_Ng"]',
#           '["--pDYWb4DzqKdAdrPcxuaA", "--pDYWb4DzqKdAdrPcxuaA"]',
#           '["--rS-rnOIZxoiDA8yctWpQ", "--rS-rnOIZxoiDA8yctWpQ"]',
#           '["-0i2KNr7WrCsDF5m0IViJg", "-0i2KNr7WrCsDF5m0IViJg"]',
#           '["-0oPt7sSKtJG1ysLwV_E9g", "-0oPt7sSKtJG1ysLwV_E9g"]',
#           '["-1WM2044r3jVZC6oQ2QeVA", "-1WM2044r3jVZC6oQ2QeVA"]',
#           '["-1oygVebK81K8JEPI6H6Lw", "-1oygVebK81K8JEPI6H6Lw"]',
#           '["-2C-Ll8cbgNMpEKokXK6Dw", "-2C-Ll8cbgNMpEKokXK6Dw"]',
#           '["-2CPhK6ik9ZBgFX_F-dkxQ", "-2CPhK6ik9ZBgFX_F-dkxQ"]',
#           '["-2ZIgbTr50xq64ODisvKhw", "-2ZIgbTr50xq64ODisvKhw"]',
#           '["-2dvQxx3cYXd5XmFdDDsDA", "-2dvQxx3cYXd5XmFdDDsDA"]',
#           '["-2slH9PUjJ9YK16b0hGxWg", "-2slH9PUjJ9YK16b0hGxWg"]',
#           '["-2wh7NTLkWEgsrLJvilnFQ", "-2wh7NTLkWEgsrLJvilnFQ"]',
#           '["-34c4hcDPIInTROr8Xtxtw", "-34c4hcDPIInTROr8Xtxtw"]',
#           '["-GJCEanNnPvwW5YggyECow", "-GJCEanNnPvwW5YggyECow"]',
#           '["-Gx5W9lIcD2UDcwLJ6S0Fg", "-Gx5W9lIcD2UDcwLJ6S0Fg"]',
#           '["-H2P_GjJWy5sFZ5j22HH8w", "-H2P_GjJWy5sFZ5j22HH8w"]',
#           '["-H89PQSv6MGXFvWJBCCeAg", "-H89PQSv6MGXFvWJBCCeAg"]',
#           '["-HWc5-NQLKBIIlBcDMfKCw", "-HWc5-NQLKBIIlBcDMfKCw"]',
#           '["-HbZLx47yHLdp98kSEog2g", "-HbZLx47yHLdp98kSEog2g"]',
#           '["-IEIG_vEijEESseR_XCZvQ", "-IEIG_vEijEESseR_XCZvQ"]',
#           '["-IHmqXaIj9L6gfJUoyAB3w", "-IHmqXaIj9L6gfJUoyAB3w"]',
#           '["-J0RIXNexJDV-mOAyhUJIQ", "-J0RIXNexJDV-mOAyhUJIQ"]',
#           '["-J0tPzkwPnyulSBE_s863Q", "-J0tPzkwPnyulSBE_s863Q"]',
#           '["-JcSG0yNk06hpNWagOKj9g", "-JcSG0yNk06hpNWagOKj9g"]',
#           '["-JpnQBGy8daXKvMvtjto2w", "-JpnQBGy8daXKvMvtjto2w"]',
#           '["-K0LoSCfh8i5U_y53Krepg", "-K0LoSCfh8i5U_y53Krepg"]',
#           '["-LA43tgCUKqAX4ws4cIz6g", "-LA43tgCUKqAX4ws4cIz6g"]',
#           '["-McT2dWG_uKAEkyVqZaUOw", "-McT2dWG_uKAEkyVqZaUOw"]',
#           '["-N4g2zaKpILmyiUO9qi8IQ", "-N4g2zaKpILmyiUO9qi8IQ"]',
#           '["-O4XZLqMJy9FmX-nVkl1-A", "-O4XZLqMJy9FmX-nVkl1-A"]',
#           '["-ODKTf6sVBn3i-M08NDHlQ", "-ODKTf6sVBn3i-M08NDHlQ"]',
#           '["-OJT4RJ0OPZ8fgCmKH851Q", "-OJT4RJ0OPZ8fgCmKH851Q"]',
#           '["-ONBja1I0ePL7-yxCefYSg", "-ONBja1I0ePL7-yxCefYSg"]',
#           '["-P4wyB0ncCDoKNpPM3OEkg", "-P4wyB0ncCDoKNpPM3OEkg"]',
#           '["-Qt0Xdu3O9PxQDw4toiViA", "-Qt0Xdu3O9PxQDw4toiViA"]',
#           '["-RB6uWNiV-Ili1mu_tapgQ", "-RB6uWNiV-Ili1mu_tapgQ"]',
#           '["-RQTEz9AaGU4uJB_dCEkmQ", "-RQTEz9AaGU4uJB_dCEkmQ"]',
#           '["-RUdfNAuUs-G8m5urhnvvA", "-RUdfNAuUs-G8m5urhnvvA"]',
#           '["-Rxzg3Iekz9NBXLTehOSEw", "-Rxzg3Iekz9NBXLTehOSEw"]',
#           '["-SCIBOTjKGJXmeMMPi-uoQ", "-SCIBOTjKGJXmeMMPi-uoQ"]',
#           '["-SFSt3FkjGfavnyMpHsZPA", "-SFSt3FkjGfavnyMpHsZPA"]',
#           '["-SrM3yq5yBBnZGn9Gtm7rA", "-SrM3yq5yBBnZGn9Gtm7rA"]',
#           '["-Ssuh_iWh-VEcqRLAK-grQ", "-Ssuh_iWh-VEcqRLAK-grQ"]',
#           '["-T6z1weFkH1XAmDWU3tgdw", "-T6z1weFkH1XAmDWU3tgdw"]',
#           '["-UbWaC43ydtM6gK4vjD-uA", "-UbWaC43ydtM6gK4vjD-uA"]',
#           '["-V4mOW2jGViwiqkavT_2Uw", "-V4mOW2jGViwiqkavT_2Uw"]',
#           '["-VTvQDLzXrlntLdo-uLqwg", "-VTvQDLzXrlntLdo-uLqwg"]',
#           '["-VfLXThgY1Qz3ODVwFuEzw", "-VfLXThgY1Qz3ODVwFuEzw"]',
#           '["-WLCdaCEA4JaGAFTK3_shg", "-WLCdaCEA4JaGAFTK3_shg"]',
#           '["-WQjN0W4CD5sw2DywN11NQ", "-WQjN0W4CD5sw2DywN11NQ"]',
#           '["-WY6gUBgI5aFsvzqhJgLlg", "-WY6gUBgI5aFsvzqhJgLlg"]',
#           '["-WjTNKDYRyagBFCpHmkqVA", "-WjTNKDYRyagBFCpHmkqVA"]',
#           '["-X6sw58z7yoFq0UuF9EoNw", "-X6sw58z7yoFq0UuF9EoNw"]',
#           '["-Y0d5ckFTrjvzxZCQoxhhQ", "-Y0d5ckFTrjvzxZCQoxhhQ"]',
#           '["-ZCctA2zuUMxUihDwhYXAg", "-ZCctA2zuUMxUihDwhYXAg"]',
#           '["-ZEYG0EXGXnLMEqOTftMVA", "-ZEYG0EXGXnLMEqOTftMVA"]',
#           '["-_5bIz9bmlMfKkH4CVbUVA", "-_5bIz9bmlMfKkH4CVbUVA"]',
#           '["-_URFnpoO-6C-cbtPoiqpA", "-_URFnpoO-6C-cbtPoiqpA"]',
#           '["-_VIDwzHvmfyxahHwWvqcQ", "-_VIDwzHvmfyxahHwWvqcQ"]',
#           '["-_arFpHzoPHvh5p-YKw5fQ", "-_arFpHzoPHvh5p-YKw5fQ"]',
#           '["-aXBwEc28UdpcNtl6B6sGA", "-aXBwEc28UdpcNtl6B6sGA"]',
#           '["-b3VxSmRw1Qot8dtDLdluQ", "-b3VxSmRw1Qot8dtDLdluQ"]',
#           '["-b7A7e2zh3CDTpgChRoRKw", "-b7A7e2zh3CDTpgChRoRKw"]',
#           '["-bR_RgtKytmFOHGPVUBcWg", "-bR_RgtKytmFOHGPVUBcWg"]',
#           '["-btcqphKk_d1FPiMRtxswg", "-btcqphKk_d1FPiMRtxswg"]',
#           '["-cP8uNoweeq8K079DrCZMw", "-cP8uNoweeq8K079DrCZMw"]',
#           '["-ch3ET0QStiKPWo1Vy68eA", "-ch3ET0QStiKPWo1Vy68eA"]',
#           '["-cj-WAPHPJjGrOkuwCaXfQ", "-cj-WAPHPJjGrOkuwCaXfQ"]',
#           '["-digbta5SDBePF4raNpl0Q", "-digbta5SDBePF4raNpl0Q"]',
#           '["-eBDRVn1mPwHFCF_hry20Q", "-eBDRVn1mPwHFCF_hry20Q"]',
#           '["-eQWM400LZchuoLOuc4x1A", "-eQWM400LZchuoLOuc4x1A"]',
#           '["-fK9wuD1tw9TPDta91WgTA", "-fK9wuD1tw9TPDta91WgTA"]',
#           '["-fTcu-OMSpM_8vjUEbh1Dg", "-fTcu-OMSpM_8vjUEbh1Dg"]',
#           '["-gUWjjws4u95dLuulwyqGg", "-gUWjjws4u95dLuulwyqGg"]',
#           '["-hWqt93mXwiPUmS12suf6w", "-hWqt93mXwiPUmS12suf6w"]',
#           '["-hYQliG6Del2qTrSMSUxew", "-hYQliG6Del2qTrSMSUxew"]',
#           '["-iWzgsleL8R-r8xFLydWZg", "-iWzgsleL8R-r8xFLydWZg"]',
#           '["-ib2qJmDKJgH_ZbtSu_HjA", "-ib2qJmDKJgH_ZbtSu_HjA"]',
#           '["-jWePOGgNdYRgz2AzzZEGQ", "-jWePOGgNdYRgz2AzzZEGQ"]',
#           '["-jaxA8fWf4-OAtyvXe61Tw", "-jaxA8fWf4-OAtyvXe61Tw"]',
#           '["-jlH7Pc6e_x3JQsF3adOhA", "-jlH7Pc6e_x3JQsF3adOhA"]',
#           '["-lCAkuXEbXVO0gG4yNupZw", "-lCAkuXEbXVO0gG4yNupZw"]',
#           '["-lhHSR1Aws4CyYC1XOPVTw", "-lhHSR1Aws4CyYC1XOPVTw"]',
#           '["-lwXPsEK2dwqPszF6zHS4g", "-lwXPsEK2dwqPszF6zHS4g"]',
#           '["-n5AeTiDdNl5rF0cJOoNbQ", "-n5AeTiDdNl5rF0cJOoNbQ"]',
#           '["-nDCHvY1qeq7tKXTLPvlqQ", "-nDCHvY1qeq7tKXTLPvlqQ"]',
#           '["-nb8_qHFjnYgQAYbkZ_yDw", "-nb8_qHFjnYgQAYbkZ_yDw"]',
#           '["-oLUNNkVi0Wdikuc4LlQ_Q", "-oLUNNkVi0Wdikuc4LlQ_Q"]',
#           '["-pLlLyzcGo6o3oiEaRPjqw", "-pLlLyzcGo6o3oiEaRPjqw"]',
#           '["-pohH4himz48odA12jVdjw", "-pohH4himz48odA12jVdjw"]',
#           '["-qju9DfLCk_evU2mfoWDXw", "-qju9DfLCk_evU2mfoWDXw"]',
#           '["-rRJS6-a9-yyOCMEG3ONFQ", "-rRJS6-a9-yyOCMEG3ONFQ"]',
#           '["-sDPjfPBVUHRRQoaGBFfMw", "-sDPjfPBVUHRRQoaGBFfMw"]',
#           '["-tMYhZ6fBkRjKidfzIUWXA", "-tMYhZ6fBkRjKidfzIUWXA"]',
#           '["-uTSULI-6yd-P-TOReLX9Q", "-uTSULI-6yd-P-TOReLX9Q"]',
#           '["-ucEQFPRCfutQpPFBCvjbg", "-ucEQFPRCfutQpPFBCvjbg"]',
#           '["-vK_08ooY5933lZ8MGb77A", "-vK_08ooY5933lZ8MGb77A"]',
#           '["-vw0HilUkEEb_VDK8jv6hQ", "-vw0HilUkEEb_VDK8jv6hQ"]',
#           '["-waPbGAS6w1Ka0tcJBd8DA", "-waPbGAS6w1Ka0tcJBd8DA"]',
#           '["-x4rcdWrlNlSYV-zkWedtg", "-x4rcdWrlNlSYV-zkWedtg"]',
#           '["-xiLPlI6JVm-W2DFWpN9Sg", "-xiLPlI6JVm-W2DFWpN9Sg"]',
#           '["0NtUzPQr3rykg6km2F6L7w", "0NtUzPQr3rykg6km2F6L7w"]',
#           '["0PNkpwSCmRifniJB88IblQ", "0PNkpwSCmRifniJB88IblQ"]',
#           '["0PVAIhp-65EZ_zSiNDEr9Q", "0PVAIhp-65EZ_zSiNDEr9Q"]',
# ...
#        '6zmLZ2bazBGBJhdzHTOrNw',
#        'pR8u8hXf1vvzoAGOoKHQqQ',
#        'xwmdDSPBvFAM9D74ftcYsw',
#        'PDI0bgHkmGrY3SYeedQxjw',
#        '3AL1MN57_mcJydVI0b9PmQ',
#        'cqcB5xTJ4R7lXxvRnS1T_w',
#        'dXk1KSuQ3Bz1EP0CzAkYyw',
#        'fbQkVymvZ0dig8umltKhZQ',
#        'W78GCXLuneV5b6prO-X4aw',
#        '9Yh4W4B2RhTNW44GdkAYEw',
#        'KACfu4N8b1RSnQgtjO7tiQ',
#        'ptLgCNXy4fHmp717IyEnBQ',
#        'WMU5k4y9Tae-pIEm5JkbDg',
#        'eGrW_3qFq3wCSLVeH0Aerw',
#        '3SHw4aZW_muE1kRSLQQjjA',
#        'KhBUg5QhBYuK8RZAe5gDMQ',
#        'LSqNv9eLh9tEY371ROThXw',
#        'wd-7MEBIsOLVnYaw9BOy1w',
#        'aOaP9Um95UY-7D_ZbTccyw',
#        'uKOqyotwWx3N2etJXBHhbQ',
#        'RqZhYS6HOxMt32zk_ChI7g',
#        'ZmrebvKKDIOKNCQaNo_8xg',
#        'Y-YEzbfJN_HWQxsEC859yw',
#        'X0aVzWJ2VIkTon782vVohw',
#        'oLUopPGK25ty8bNPaDaTLQ',
#        'ubHIeNUBgWXPBYjNac2Sjg',
#        'k37i1EW_x848o_n1ATcErg',
#        '8ipYS6TCeVPCOgjRObphUw',
#        'GdUbj1Y9ifnBrHZyMQKwQw',
#        'KjtmHMNmihmDkRI3zD9JVg',
#        'BG8T5qmOTbfp8WW7FXlDww',
#        'xuhsjS8XP1OaftN3yrW4_Q',
#        'OAHRMd971k-yDQwRxzgc2g',
#        'baHb5T01_MnnhQFHRCR0fg',
#        'KP5OncF2jhT7_J1phHPPww',
#        'vUCtnBRPV8KeR2T6MnFJ5w',
#        'whNtPvVGI4cCTWa_Qv5Yiw',
#        'vvnbAFb-aY1ykHdq9oMB_w',
#        'V1pEXtJgaczutwK7YLzrHA',
#        'QCtTzF52y5MuGXXBwJ1srg',
#        'Ow7Aa0xUUk0NaXnv_417IA',
#        'uxqn4kSvEj6Q66egwYrKYQ',
#        'SbMcDs06t7IPgXALJ2aNZg',
#        'jcQ2ykQjVjSiVFf0EtH6eg',
#        'yfLlpU8h1plvnMgui6xwRw',
#        't8M72tG20YM3Sk4pzQzs8A',
#        '6FfvGK0ULZzFH2LmyOd0Kw',
#        'nwBSxYuS3FzTf4-1SmgiiA',
#        'goUEGY9ICzjl9zp4HfJ-sw',
#        'SQX3MkZ2ve5N1guTtAq6eg',
#        'QHzOlsTXfspSOMJ5SCxeCQ',
#        'LmGvuqllvutbtbkjgPOoJg',
#        'naaYU6QewUMhxPt3XBXQVA',
#        'TFh7OZWE-sjN91AW_RI0Pw',
#        'NFTPkaT4-rgbbZlyF1b-0Q',
#        'UthNqQ_sNhHh8jBrdjVAoQ',
#        'jn7yLpUT9OvU0UMlCux8XA',
#        'RAq2x5Wr7nqpiGt3Hge_pA',
#        '2Ix7aG_r0mmvO1HBnIL-IA',
#        'Eynpakzpkx5i5oFarjaMVg',
#        '0NJSO8fiUwzEsvxLbDAZYA',
#        '6R1I9wFvKV1A8razp0No4g',
#        '09RuQs8N7UcvTDyW9HzGPg',
#        '7o1UMjxlm3m_Z04JmzS5hA',
#        '6rXUoohWBW5xV7AKaXeFOQ',
#        'cx5rIVMN-FXwBkl2Kbot7w',
#        'O3iMLiyTA_MVTnKXLZ-Fuw',
#        'prBYQOdCXSjxV5DtBt37Kw',
#        'IayDnngl0NooAbcoo62j-w',
#        'mPE0EmZlMkChHtDXS5iYtQ',
#        'CXHwIvDKasBQrv_Uztgs2w',
#        'Pm6qD9G_xWLoV24YIN8gwQ',
#        'GApqfwJMxg4t2tk3K2PpMw',
#        'unkGQNCeDkAUOaZAg8HC5w',
#        '-5iuX3tPbwH5LpoWN9QhMQ',
#        'JDwp5guESWuyng2MSBYEjg',
#        '1PGZ16uk7eM0yaQnZLSitQ',
#        '-P4wyB0ncCDoKNpPM3OEkg',
#        'wQNguYCgwWID6XOPEpYuvQ',
#        'JoGHgUENrqTXqkxhXClEXw',
#        '0hIXH9jMdHov1VrLC8ujUg',
#        'Q05tSZCKVvPOL-IV-lj2hQ',
#        '8jslfcsfU2BgthKAq0HynQ',
#        'W59CQDeBnA06VadX5Hk2Ow',
#        '7pTSUbvuKYowZfN0bGSy8w',
#        'k0StgZ2DwBeEB5MXYnwfVw',
#        'KTNahGeJsPlcXDN9qfDpvA',
#        '4mDF-D8mECfsYLCFQmB7_Q',
#        'A9XGPIn4ZSGVeB2AGoF2aw',
#        'M95l1IE_WLcdh-RM08tMBg',
#        'opYC5Ee1ErY57PBckH_4bw',
#        '1oG6bY7TuWEConNDdVi22A',
#        '9wxGE92uD9hoXPu-kO6twg',
#        '-SFSt3FkjGfavnyMpHsZPA',
#        'V378VWx4D8BstWNRFwDULg',
#        'MVGOwDiiSW358YQzOAJr8A',
#        'fM2IXobO9Ind3-hs1Qy5GQ',
#        'HLYVOCTFwTvJfNfhGixjBg',
#        'iSskf1cWrkpfu1wJbGlb-Q',
#        'ZGD4WacjO1v4Ath3Qil-Sg',
#        'w0LzrzBFdRO1atLCyNOplQ',
#        'EGITUFVLb87GRKapMtZg-w',
#        'uz3bn1LnXUGPteDoHYhcRQ',
#        'vZp-KUODRmP_6mb7AliDDg',
#        'w0teKWyqZMzR0f6mNZ57yQ',
#        '-sDPjfPBVUHRRQoaGBFfMw',
#        'BYfBlLIu9lp5GNcuN3k-vA',
#        'KHhtmKYFOM9nUW8U6_rZGw',
#        'NL-pATcAaXHwxrm7ODwEig',
#        'k5UmjRMn-QSpL7BJI2KK9A',
#        'Zzu_3opbupiIvNuXl5Q58A',
#        'rpG_nVPH1FmOL55q4R2bpQ',
#        '3TagDMAD_Ciy0_Sg3kJf2w',
#        'BcWx80K4i0LjIkH40o_Kkg',
#        'QZk_7gXhpNTdk34y0cu_wQ',
#        'ysAW0b2B5xk1d34L3rwf5Q',
#        'APW4-ESYGTIn17mY189Osg',
#        '7ZAIFmz5fBaCvCGXrJZBkg',
#        'hpky3Zx7oKzjGL3Yb89irg',
#        'inJ9E35w_B_parvNpAM2CQ',
#        'LPCelCpWQgeiya-4WdtPOQ',
#        'TXoxXn3IETBBJxZQMQK3rw',
#        '6Mf5mu1yINYEftip-xNzeg',
#        '2J25ayD4_TMyoBbi-E3WMg',
#        'rQCTWNMzIZTfqWEAjxDpKQ',
#        'cypV1uH8jbV0CaGYvft-Aw',
#        'KLQsP566eEuWq6DBaccrug',
#        'rOYVkIqBDQ-shKwUhJp7gw',
#        'vTNm04guTgOT5hCmGSN5HA',
#        '16DQ6couFc4hsvv9B48dyQ',
#        'Q1Ca8WR1BeEP3zKRpH4OBg',
#        'p-CA14qMUraWvppFqOsSgg',
#        'WW35xBzbnXGciLjDHidaGw',
#        'ixPTo6Hum7nNZ7A4VPhTXg',
#        'zYm7kBoNBLDGh_fPiPBR3Q',
#        'ZiQiMlvgk19GrEEkN9kyRA',
#        'c0xlgkMW1iDu7gUDPs86hQ',
#        'dpGKdWz6y7ymYg3tpiPNDQ',
#        '0Hjr4I1wYcFXiHEvHnl7dQ',
#        'aGuJYGl_Vj6ctot_1mW3tA',
#        '86D14cGmw-D5VOCBJX5sJA',
#        'i81aJGVWQDKoPzNa7xKJsg',
#        '9fjdQvNl1yWKCNgo0VaCyA',
#        'm_QNYoxlFmZ9tS-UWkT5fA',
#        'xaiOUSSSf9rbYz_4e6dIcg',
#        'ZsKdeBkVM4I_GbXlXo8IKQ',
#        'tIDld1zfzEndqjdfwarxRA',
#        'NTh_DCZmHGG-Za11SD643Q',
#        'mp09lz82UmvIlcDYitxU_w',
#        'sLtxlJc83eIebkmlmw2JLQ',
#        'Qoi_x6vt2FgHhK_YIcEKfA',
#        'H_oc8E8EDKYaBM21pPHkyQ',
#        'BkhFlGmMevcojZBNFTgIqw',
#        'wA7v8fiuWZ4qOW12HAVcGg',
#        'w9MojhsClMHHKK5pa8gcBw',
#        '44pQjQRUPU_Yad38OMEUVw',
#        'GEF7sP9QrjYlS5NzEn8sPQ',
#        'laElNpr0C23diPSsx12Nvg',
#        '9WYbvHY-IkZQqhYN_5zMaA',
#        'h8zkJQxkDdclZc5nh_Vl2A',
#        'Uc6PdjT_MO5bRPQsUUEy5Q',
#        'Xbu-HcPKCyLqyZCILwQuwA',
#        'MCQIa9tdb5G0QU63565cIQ',
#        'SmnnO59nMH8A9RT5R2aloQ',
#        '6HfGx_gVu1IHFnPL66kAOQ',
#        'lXCFcmhoRsyW-mnzzl6fkA',
#        'tQX_u6BqyvpGaPzeCyRrzQ',
#        '3nbvqLJwuwNn2gymccn5Xg',
#        'xT41eqUSsM_MDE1Vjhq20A',
#        '4DVN5Uun3i-nmTIIOBhHog',
#        'c4VIDJSf316OxukNbteGpQ',
#        'zBLEN-Txkv-HwQnQbWIxbg',
#        'nAXL272uOLU5JsUVo15A4w',
#        '_DfNFoairZaX6hHweRYwBg',
#        'jkXp6Klo3rMg1X7DVQMcUQ',
#        '_uOkk1lO4LXWU22DwEhj-Q',
#        'UaE5Wru0lD5kVIWbnQ8xMg',
#        'un-XddanDbwKzBAeTLpCzA',
#        'J1c810pTu1Z7C7XWB-SJ_w',
#        'xv6cWLNHjudR-_8WinCOtg',
#        'llYsxQ0IuKh0HXULlqu6fw',
#        'hMO_wBLj2ioU4goSOP0arg',
#        '_pbx96FZ3eHJw-V_R4h-Vg',
#        'NH9LSB4Qz2v0fHTMz9sQ0w',
#        'hAmuto6UndVroyd_DaD-TA',
#        '1Jxha8s4R-awVWEdCq9o3A',
#        'FZz7190Kn_o1AdV0QuwTRQ',
#        '9qSeYLlh-vOHk9XX7v1LHA',
#        'uaKXyCNVXWdfOOdbM88pMA',
#        'iKKYu3iwTViMgCON-VBApw',
#        'BqnygnNqxVDD_0ct_fN_mg',
#        'U_wKqFYSpD8D3CBl7e8ENA',
#        '6pkegB2817FvPHwp9LVlxQ',
#        'Yit7GvwzEYbIzkNhxeqC7w',
#        'LjgiE_EbpBdIz4JyVUioTQ',
#        'QC5k1-cZ5v22ReHGDeavfg',
#        'fXsdsGnTntaRWbfUxP3wXw',
#        't-bcEvAM8oE92tm9HBr7wQ',
#        '46xFjSCGApTaie5zhukvFw',
#        'w7OIfrhCdKyhDRiaBEVLJg',
#        'ErYythZEMC4ly0-nWVFIpw',
#        'zmPRS6bjajqsyeuRVi4TKA',
#        'C_77HIyBKjfW5nLhkf4_Dw',
#        'oJTDq5GFLK5i8s_mFbHxSw',
#        'kGl2zBnLWTUBQLFkd0u_FQ',
#        'S8lscv1Sn0r0p15VtBVZVg',
#        'l7b33ubze8Jqw7C4I1CAuA',
#        'JclLNtpqXecP03_oCybEAA',
#        'UYxGgnJ4Z2lOehK23HSIlw',
#        'cl6i04XBzk7pQoId1eUD3g',
#        'ql963aVCQxQjnZnl8DU-VA',
#        'b70Ad96YzfsHMU6IljIqHQ',
#        '7_Xw-DRHivrSNetCmgAcLQ',
#        'HU-S7rzIE1qDkCy4L54CHA',
#        '-HWc5-NQLKBIIlBcDMfKCw',
#        'aQbe9DP7JnhDVbNJCqaGcg',
#        'wiO4EYRxuBhhDj924PlIIg',
#        'FSTmzo0beEVMRMSArcp4fg',
#        'SaW7HrDoO2oedwTe9DeYVw',
#        '0hCrds3sgFAYzsZolg3jcg',
#        'ydhQU-w03WwrGhXPs9tRVQ',
#        'pWA8iauMapGgshXWJDzLGQ',
#        '4pLmG5N-seQ28r01B_f4mw',
#        'NxFEx_G4AIP8S0i2XtGZeQ',
#        'sgKIKeFXSUHLeOcX1q8nQg',
#        '74XwxDrQKpbk0lWKTmSzJg',
#        'YhRujloQ_ioY_WclZbJuQg',
#        'YT5CjacTllBtvMaMJS3IbA',
#        'dLMA55z9wdDkUIO-rnhOmw',
#        '2VuOLrhe2Iu_FRz1gEIqQA',
#        '4xSoCvHcFLoZW8tyxMqrpw',
#        'xqFB8Vri9BTOGWmsJW9QAQ',
#        'PfmbhnCC7nrcvD6QBMEDhQ',
#        '5sO5Mc1iwXsiW2iqLJTmOA',
#        '182K66D5Wxv_bFm3LGMMZg',
#        'mqXBKsv5O2ETyD27NY1n2g',
#        'ItFbCynqVhfSU-TXR90z9Q',
#        'iziD-_9RGpU1CHNPvGHGiw',
#        'SwBhaxfQPbyhsi0QHUAN0A',
#        'u-9xYWqe4CuHd3DZL8iLcA',
#        '9hawk7NHHs5hsPIDvF-Yzw',
#        'CmjvsiafnWH60fuYz2LCmA',
#        'V2hqC0b1d6Yn0JMGg4DCPA',
#        'RCGnBKN---1zDpPGUMIUgA',
#        'fzOy2gQYML9Pb9XVzWAL2g',
#        '0k2iNiQ34jZTrbrIINWahA',
#        'cXyE-DkfeYptk2BYu_-uwA',
#        'ECBgKUFxuA6YjqHqDBqVmA',
#        '338D7EQfInzHV8Ve1b0-eQ',
#        'tA4igim9d4BTb_i0dD5QfQ',
#        'jYKQl89MNi-73MVTi-fcAw',
#        'g__reLE-nkT2HrRDE0R55A',
#        'MigTVpaAnObaYcnf6jfL6g',
#        '8fGCwxodHba1u8p3rfv8bw',
#        'BAcfjCEhizeH5Uh_TBq1_A',
#        'x8MSRDnEFH-jBEumWfcLew',
#        'HmH_bM4tFsqDtOypRlnMeA',
#        '3PLwhjfiNJH_bZ1W6HFRZA',
#        'y-cD16w_B2dSxE_iX1RBXA',
#        'yjkwS1lhEBbGCMd0-PK_Tw',
#        'XBFPFjjCYZhd2zmZLqRdEw',
#        'A8fwjVnwsO5AX9avki9NFg',
#        'TpIhYxu_bwkj0JbEmEPg5g',
#        'BPZtdhDjbDC_czVYqvDZlA',
#        'sZv9RBbLG5PBO3AJB33HUg',
#        'zptpEiPvCTlCULHPBe-P7A',
#        '-LA43tgCUKqAX4ws4cIz6g',
#        'Sl8hH3uzlFoO29Ip5cIKeg',
#        'OQ1tbQ2V0SpNfDikkd8Zuw',
#        '7YmGkwGXlHCJ4hTPYySTHw',
#        '9z0jRISq3yl_szQCXk06Dw',
#        'AwdCbWoYtX0r1A0-Op_HQg',
#        'a2ITIJRAY4Eo-xTH0vN95A',
#        'g9VjloFtS0S2p4_XoV1ReQ',
#        'tqsIELQ8kUIOaN5Q1afS9Q',
#        'P4MW1ALOA3zo4SyeCXFdJw',
#        'RnqU698MbIjq_eZHEzYL6g',
#        'o__FPxtHhuWCdoDe3Bjk-A',
#        'N2ugolGYZpc0h20JTi9bng',
#        'u7RLhxs1RPEChKjYocHq8g',
#        'cs7i8-NtrT2P4dMYa2fX-g',
#        'PBqj5MffQMKEIST0xrUmWQ',
#        '-eBDRVn1mPwHFCF_hry20Q',
#        'JAoDt-6rkzhOzxwQfXB9qQ',
#        'yV4GUuaEHqkbi5IvluMqAw',
#        'kKHOXd5XRZlg-VQZHIgDGA',
#        'iw2SbQ8sude6uyklxzQzLw',
#        'yxQcngZTpCz7RysGrbd5kQ',
#        'mMPvgBgqON8pia_4AgGTUw',
#        'qs9d6iGos9UO4BzhVmJ9UA',
#        '44XzgUMyWSU2bS5PGdrvoQ',
#        'GsjhkrlnayO4MC9DG9HxgQ',
#        '9kZPUwuRd6PLGSJS9g85RA',
#        'IS8cnubq4bd4tlLtKA8qLQ',
#        'd9vapPUlJCSSrltRRKO9ig',
#        '5JiFbBsbUdb-caBZWRyMSw',
#        'X0yZMHwB1yUyzISAqRyYtQ',
#        'yI3k2qiaAhYZ5Q8MeS0TAw',
#        'i3Um5He4cghAM7iZ5y5jOA',
#        'SYy81zP4MPF4DtOqjRq4qg',
#        '0iCjkCl1uox1j-WYtHH14A',
#        'jbG1bedq6vZOIZAErS1sGA',
#        'YFIl9ohLnlo05iJn9AuKaA',
#        'H6VIBm2UHwlu3FE8zPsgoA',
#        'xtNY0tB7xs0GlXc9V9aKOg',
#        'FQizb_NOd8Q6lWO4aEuF2g',
#        'guNhL9Utad5On3Wz9VxzAQ',
#        'RykQaoqinB4ZST_F-fODZg',
#        'wHicEIN-xE-uZD_JoyrzTQ',
#        '9yphWF-efIPmAKorPRXl0w',
#        'IFDNQNwdKC-IOUSkyqAtyQ',
#        'zkdDg7kPOgZssR2a19itbw',
#        '_S5r6Ft2kjF3YDbGk-pt4A',
#        '-b7A7e2zh3CDTpgChRoRKw',
#        'wHyRfaCUBVG9GfXkNIzLzA',
#        'MCIhGrT5GlHICWQRO9PdxQ',
#        'vnVq3M5FuCu_vl2e12JWPQ',
#        '_3VCzu9a79nrU0YA-WvUCg',
#        'rW_9aLoDvGnkEaqJTdhiBA',
#        '35xe-xLwaYiA6ZfFvQC29w',
#        'M2S5ELqHjz1B1booBTN1dQ',
#        'PxrXnIk2gAkk-dqmsupbfQ',
#        'E34saIsYxyuKSJhWwmlb0Q',
#        'VEUDz06L882oWf_VCmmDxQ',
#        'XMnh6RVeJU71O7iWqX65dg',
#        'XP7CmK61lneYpjHTWMkbdQ',
#        'xRNY8AqhRc3AWCkX8moDXQ',
#        'HBR8cAWnMh_U1JSchTvWnA',
#        'MWrSqr3VmBcSKT4Uhk695g',
#        'ubIwwAx-JxZmgSoJgW_0og',
#        'CSRbFLgUDO1cvr3OlRMLHA',
#        'dikP2bqi-zIUISB_TKPRtA',
#        'kBbNlvMglJRrPmlpdCHLuw',
#        'jIC4rTuCBTBaBDmgiAvaMQ',
#        'ILK67sPbd-MF_921BZgUIg',
#        'zTGzoge9b_U1m7lExiHqgw',
#        'izhlJiI6Opp_eOBOe2idCQ',
#        'Mxlw3cSKkWv5o4HdRWGTPg',
#        'oJRjeio1OBablDFr--__Xg',
#        '3ds7tczq1T8m0sUWhr9q6g',
#        'ttsYdt2wWY5fgAv_aotG-w',
#        'xHnw7rFlQI2OcLUgL8IgGg',
#        'uCTNQAoc5LmYOC3569nboQ',
#        '3yI-7C8JzbG-ZaSqAGHMAQ',
#        'fBNjTSdPJ1mtTzIHYpQnDw',
#        'wEPbFKuFh7Vjt-Nf_ctTGQ',
#        '5OpYqBPvnAGDxEgbFGrq7w',
#        'j7c9WjWoYK_JpitKoRhE-A',
#        'vU2BXpEwI_5mLcLAkRrbhg',
#        'QcVA0SY3xV1ZXd5WYO7BUQ',
#        '_4aXcnsN9iboENHK7cGD4Q',
#        'vyKKuYDTofiV1oJDN-g8Lw',
#        '6vWKezveJpsWgjl5Cd3l-g',
#        'w7KLf3anjdXNXNVplvOOjg',
#        'OfMy6t4SSFXpzsBfNUkldg',
#        'co9kHEFBAOCsz0U_07R0IQ',
#        '2kuhZOrWcLYe_XePccr4lA',
#        'zI_MuZRJEAFKBsOX9oZ8uQ',
#        'IRaLSSGLusS0jyUeh9Invw',
#        'cP557FVHmNg4cEk-LplezA',
#        'doBVyvdRV06W-hZOm7zL-A',
#        'R5-SqYVbT94h5PN760gFng',
#        'QEaBiJMnvnGpQlE7Cb_4Ig',
#        'eK5SVQ2-Bvco1Nrcl-lgxQ',
#        'jYMxtQhB1YP0dfhr9P96ng',
#        '35BuVcbDU7D9mjmruxmnEw',
#        'yRl9k0zm6kWz9LMGqebaIw',
#        'DF5Q_gupAkQKCA39RKRVVA',
#        'enarGotTJq0LCk2bbCYqGA',
#        'Wu9y5yy_vLuumjEUkhfBDg',
#        'tnPjcpTSdCZB7LGoH1ZjuQ',
#        'lXUVhOtcfOT-g94qTh-kgg',
#        'u-6QUJ60HllQdUMiTmE6ow',
#        'gcycWnQWsrrE5NEpcBuuRw',
#        '2y4IM4_B30QW3718m98-dA',
#        'zmsdloVmluH1Ht2Q6xhK9w',
#        'gjdY_sQ_1AAESojSOshrOA',
#        'UWk9hczxAjMT6y5C3826fw',
#        '-_URFnpoO-6C-cbtPoiqpA',
#        'iSJlDpeYlhUYLGpkVwolMA',
#        'c1PYMS8qxxjkzsGbJ7IMtA',
#        '-5fXJjU1oeWnCHW5MPOuxg',
#        '5SFxxTmzXVZjvAYaIVOZOw',
#        'pweBNIhbN9xRz7u4ac_Wqw',
#        'Lxg0Sama1HrZxUBvxCIZew',
#        'BycQazZk1gvq8tZC-R7QWg',
#        'vs4EAGPkavNHZrnSVgLMAQ',
#        'l46sjKxPfJCzCJCTQEEKUg',
#        '6IJ62H9UJi0p55XviPgeaA',
#        'd4X53gNSnGNAD8P9dqPxHg',
#        'd-_wqnq9HU5-Cbmnm54yyw',
#        'GyC36Pn0Q1-qHnqXys6yFg',
#        '-jaxA8fWf4-OAtyvXe61Tw',
#        'P08EbPAfAJ_wbJu9CDPZAg',
#        'tJwHRvOF8QlHy4Eu6FKfYQ',
#        'R1-ChOR_wQKbf9Xlpii92w',
#        'c5UaaWzJwleA-23NEsK7uw',
#        'KTtjMPu1jCR0y_fcv28uZw',
#        'baOWO87-In4i4JYbRFMPnA',
#        'jlaT9nNS1IJLy6RC9rSnDw',
#        'pN85_0Xr_cYY-F-PW_nzhw',
#        'wRzkbYY7Dmi8fkgeoYvjVw',
#        'yKoYrahfJtHnpYXnZMg0eQ',
#        'TIO4TylIjSenKmuzNzv0Mg',
#        'tiS2b45jLTEyJiIHkVJdJw',
#        '1oapj0mo9XSyj4RVzSZ1cg',
#        'SsF6aOb9gQJCGYDr0zX_1Q',
#        'M2ZrrqseHE5xssUrOL0Gtg',
#        'sRMMcGGcuBtsxBYQdybyQw',
#        'znsHfZ2seiCAiO8NGQm8-Q',
#        'a_ts6C7QntisENtyitJRBw',
#        'w0eMUGG8nLtQBSnCbURbZQ',
#        '_wfMydyx6Mlf5Uybg7XWNg',
#        'uyQGW7kZKk90vEwGo8A7mA',
#        'EJcIDYDrqptWxRx19Fu_Lw',
#        'iA6wXhjrxntrmBmzcqrNPw',
#        'kl1vPc0N7t4NPRhOD1LLrA',
#        'ENFmfflwE7qo0jvTUxWjVw',
#        'NpQowTAUYGeylRCAsJx9UA',
#        'XnYHr5-NpgSY-LcrNUfWuA',
#        'ZbUcu1E6jWDysKrR-f3lww',
#        'qfGaFhIB-cq9VI5hlY5tOw',
#        '3yQCkHel9UnWBVHUkGyfzA',
#        'ZtvLjP4MAyIdXKm4pIvNSg',
#        '6LgaEHS0k29b7AGjgPwCRg',
#        'ClD3hvS0EZXMPYV8onMJdA',
#        '1_nP46RfAT6GQOhIYEXZVg',
#        'IJxdSdteun-ZFDMMBp__Fw',
#        'yHvfeF-HdvjxtCKRZR-rnA',
#        'wjoFiONsq5zVYzjmhrxMjg',
#        'LFOFdqYB_LW9wT_uOa2FPw',
#        'tKmyrOsGaymIBVqQ3eRJLA',
#        'DgeVBg0BKgZGtpQ85G5VGg',
#        '3emutOUAcgDUtwiXGDnYGQ',
#        'nOry_Gpzt05z0yELmXBFcg',
#        '3PdwRU4ZVgWbWIcwYktlxw',
#        '1lxXojRbsKuIXQPVDjmo3g',
#        'ZvI9Ytqx_S_kahct3YzS0w',
#        'gmkwys-_V5EzB9FYca_iQA',
#        'yed0V7egMTQaxU0gpxGoZg',
#        'HLasBlWiSj9TH14Qf8Y1kw',
#        'dx9NQY75MfzXe4EvpgAu_A',
#        '4JZV4Cogoe4R0_dOPE8wmw',
#        'ljspm6edHnndZ9mQvXd8qQ',
#        'J_FkKjScVhWM0FKF57DA8g',
#        '5OdQ3q8KiMsWjAj5etB7oQ',
#        'sTfVZ9xo36tU8R5DnaCGkg',
#        'WCxPksSXiCXL9zmltEKmMg',
#        'uDw2YZQH5L40qwTer8FLyw',
#        'nWV4kqTl_57hJ65bFhzQPA',
#        'JRZvCv32jMEg4DooClFFvg',
#        'cQ6hlVWqcCZiTB4gWKfW9w',
#        'Hz9t8Z8ftKRF2-jVCWLzsg',
#        'TXKsettXQVYQeSLnT6214w',
#        'hA_21KNZ-qpA23hN4_txqQ',
#        'sBy7gqCUAi28mlUdsMhlkg',
#        'TbPMnFpm2vmdSqkvG0nyIA',
#        'x-64ogehwhEXOfo_NEE5mw',
#        '_UB-8QKlvKVstiy-AF0Yeg',
#        'hxVtBsMgkbjZk1lNA3tL7g',
#        'jXD9rVemQyEHLv0IWGf10w',
#        'GbNjXIjviU42PfLu703-JA',
#        'gzfaaCMDbwNDU4-xAwPQCw',
#        'vdv_HaU7ZIID12KB9mG9Vw',
#        ...]}}},
#    {'$lookup': {'from': 'user',
#      'localField': 'user_id',
#      'foreignField': 'user_id',
#      'as': 'user_details'}},
#    {'$unwind': '$user_details'},
#    {'$group': {'_id': {'user_id': '$user_id',
#       'user_name': '$user_details.name'},
#      'review_count': {'$sum': 1},
#      'avg_stars': {'$avg': '$stars'}}},
#    {'$match': {'review_count': {'$gt': 5}}},
#    {'$sort': {'user_name': 1, 'avg_stars': 1, 'review_count': -1}},
#    {'$limit': 10},
#    {'$project': {'_id': 0,
#      'user_id': '$_id.user_id',
#      'user_name': '$_id.user_name',
#      'review_count': 1,
#      'avg_stars': {'$round': ['$avg_stars', 2]}}}],
#   'cursor': {},
#   '$db': 'yelp'},
#  'ok': 1.0}

# %% [markdown]
# One review at restaurant per user query

# %%
pipeline = [
    {
        "$lookup": {
            "from": "business",
            "localField": "business_id",
            "foreignField": "business_id",
            "as": "business_details"
        }
    },
    {
        "$unwind": "$business_details"
    },
    {
        "$match": {
            "business_details.city": {
                "$regex": regex_pattern,
                "$options": "i"
            },
            "business_details.state": {
                "$regex": "^FL$",
                "$options": "i"
            }
        }
    },
    {
        "$group": {
            "_id": {
                "business_id": "$business_id",
                "user_id": "$user_id"
            },
            "review_count": { "$sum": 1 },
            "avg_stars": { "$avg": "$stars" }
        }
    },
    {
        "$match": {
            "review_count": 1
        }
    },
    {
        "$group": {
            "_id": "$_id.business_id",
            "single_review_user_count": { "$sum": 1 },
            "avg_stars_for_single_reviews": { "$avg": "$avg_stars" }
        }
    },
    {
        "$lookup": {
            "from": "business",
            "localField": "_id",
            "foreignField": "business_id",
            "as": "business_details"
        }
    },
    {
        "$unwind": "$business_details"
    },
    
    {
        "$project": {
            "_id": 0,
            "business_id": "$_id",
            "business_name": "$business_details.name",
            "single_review_user_count": 1,
            "avg_stars_for_single_reviews": { "$round": ["$avg_stars_for_single_reviews", 2] }
        }
    },
    {
        "$sort": {
            "single_review_user_count": -1
        }
    },
    {"$limit": 3}

]

results = review.aggregate(pipeline)
df_single_review_businesses = pd.DataFrame(list(results))

print("Businesses in Tampa with High Number of Single-Review Users:")
print(df_single_review_businesses)
# Out:
# Businesses in Tampa with High Number of Single-Review Users:
#    single_review_user_count             business_id       business_name  \
# 0                      3148  QHWYlmVbLC3K6eglWoHVvA                Datz
# 1                      2962  L5LLN0RafiV1Z9cddzvuCw               Ulele
# 2                      2831  dsfRniRgfbDjC8os848B6A  Bern's Steak House
#
#    avg_stars_for_single_reviews
# 0                          4.14
# 1                          4.17
# 2                          4.26

# %%
# explain_cmd = {
#     "explain": {
#         "aggregate": "review",          
#         "pipeline": pipeline,
#         "cursor": {}
#     },
#     "verbosity": "executionStats"       
# }

# explain_result = mydb.command(explain_cmd)

# print(json.dumps(explain_result, indent=4))

# %%
mydb.command('explain', {'aggregate': 'review', 'pipeline': pipeline, 'cursor': {}}, verbosity='executionStats')
# Out:
# {'explainVersion': '1',
#  'stages': [{'$cursor': {'queryPlanner': {'namespace': 'yelp.review',
#      'parsedQuery': {},
#      'indexFilterSet': False,
#      'queryHash': '4E7FE95E',
#      'planCacheKey': 'D8CBDF1E',
#      'optimizationTimeMillis': 0,
#      'maxIndexedOrSolutionsReached': False,
#      'maxIndexedAndSolutionsReached': False,
#      'maxScansToExplodeReached': False,
#      'prunedSimilarIndexes': False,
#      'winningPlan': {'isCached': False,
#       'stage': 'PROJECTION_SIMPLE',
#       'transformBy': {'business_id': 1, 'stars': 1, 'user_id': 1, '_id': 0},
#       'inputStage': {'stage': 'COLLSCAN', 'direction': 'forward'}},
#      'rejectedPlans': []},
#     'executionStats': {'executionSuccess': True,
#      'nReturned': 6990277,
#      'executionTimeMillis': 365113,
#      'totalKeysExamined': 0,
#      'totalDocsExamined': 6990277,
#      'executionStages': {'isCached': False,
#       'stage': 'PROJECTION_SIMPLE',
#       'nReturned': 6990277,
#       'executionTimeMillisEstimate': 4803,
#       'works': 6990278,
#       'advanced': 6990277,
#       'needTime': 0,
#       'needYield': 0,
#       'saveState': 920,
#       'restoreState': 920,
#       'isEOF': 1,
#       'transformBy': {'business_id': 1, 'stars': 1, 'user_id': 1, '_id': 0},
#       'inputStage': {'stage': 'COLLSCAN',
#        'nReturned': 6990277,
#        'executionTimeMillisEstimate': 3848,
#        'works': 6990278,
#        'advanced': 6990277,
#        'needTime': 0,
#        'needYield': 0,
#        'saveState': 920,
#        'restoreState': 920,
#        'isEOF': 1,
#        'direction': 'forward',
#        'docsExamined': 6990277}}}},
#    'nReturned': 6990277,
#    'executionTimeMillisEstimate': 5005},
#   {'$lookup': {'from': 'business',
#     'as': 'business_details',
#     'localField': 'business_id',
#     'foreignField': 'business_id',
#     'let': {},
#     'pipeline': [{'$match': {'$and': [{'city': {'$regex': '^(Tampa|Tampa\\ Bay|tampa|TAMPA)$',
#           '$options': 'i'}},
#         {'state': {'$regex': '^FL$', '$options': 'i'}}]}}],
#     'unwinding': {'preserveNullAndEmptyArrays': False}},
#    'totalDocsExamined': 6990278,
#    'totalKeysExamined': 6990278,
#    'collectionScans': 0,
#    'indexesUsed': ['business_id_idx'],
#    'nReturned': 458458,
#    'executionTimeMillisEstimate': 361700},
#   {'$group': {'_id': {'business_id': '$business_id', 'user_id': '$user_id'},
#     'review_count': {'$sum': {'$const': 1}},
#     'avg_stars': {'$avg': '$stars'}},
#    'maxAccumulatorMemoryUsageBytes': {'review_count': 33953896,
#     'avg_stars': 25964744},
#    'totalOutputDataSizeBytes': 271980510,
#    'usedDisk': True,
#    'spills': 2,
#    'spilledDataStorageSize': 13555523,
#    'numBytesSpilledEstimate': 186138120,
#    'spilledRecords': 443186,
#    'nReturned': 442965,
#    'executionTimeMillisEstimate': 364429},
#   {'$match': {'review_count': {'$eq': 1}},
#    'nReturned': 429298,
#    'executionTimeMillisEstimate': 364548},
#   {'$group': {'_id': '$_id.business_id',
#     'single_review_user_count': {'$sum': {'$const': 1}},
#     'avg_stars_for_single_reviews': {'$avg': '$avg_stars'}},
#    'maxAccumulatorMemoryUsageBytes': {'single_review_user_count': 1252152,
#     'avg_stars_for_single_reviews': 957528},
#    'totalOutputDataSizeBytes': 3857733,
#    'usedDisk': False,
#    'spills': 0,
#    'spilledDataStorageSize': 0,
#    'numBytesSpilledEstimate': 0,
#    'spilledRecords': 0,
#    'nReturned': 9207,
#    'executionTimeMillisEstimate': 364765},
#   {'$lookup': {'from': 'business',
#     'as': 'business_details',
#     'localField': '_id',
#     'foreignField': 'business_id',
#     'unwinding': {'preserveNullAndEmptyArrays': False}},
#    'totalDocsExamined': 9207,
#    'totalKeysExamined': 9207,
#    'collectionScans': 0,
#    'indexesUsed': ['business_id_idx'],
#    'nReturned': 9207,
#    'executionTimeMillisEstimate': 365142},
#   {'$project': {'single_review_user_count': True,
#     'business_id': '$_id',
#     'business_name': '$business_details.name',
#     'avg_stars_for_single_reviews': {'$round': ['$avg_stars_for_single_reviews',
#       {'$const': 2}]},
#     '_id': False},
#    'nReturned': 9207,
#    'executionTimeMillisEstimate': 365142},
#   {'$sort': {'sortKey': {'single_review_user_count': -1}, 'limit': 3},
#    'totalDataSizeSortedBytesEstimate': 1323,
#    'usedDisk': False,
#    'spills': 0,
#    'spilledDataStorageSize': 0,
#    'nReturned': 3,
#    'executionTimeMillisEstimate': 365142}],
#  'serverInfo': {'host': 'Riyyas-Laptop.local',
#   'port': 27017,
#   'version': '8.0.1',
#   'gitVersion': 'fcbe67d668fff5a370e2d87b9b1f74bc11bb7b94'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#   'internalQueryFrameworkControl': 'trySbeRestricted',
#   'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1},
#  'command': {'aggregate': 'review',
#   'pipeline': [{'$lookup': {'from': 'business',
#      'localField': 'business_id',
#      'foreignField': 'business_id',
#      'as': 'business_details'}},
#    {'$unwind': '$business_details'},
#    {'$match': {'business_details.city': {'$regex': '^(Tampa|Tampa\\ Bay|tampa|TAMPA)$',
#       '$options': 'i'},
#      'business_details.state': {'$regex': '^FL$', '$options': 'i'}}},
#    {'$group': {'_id': {'business_id': '$business_id', 'user_id': '$user_id'},
#      'review_count': {'$sum': 1},
#      'avg_stars': {'$avg': '$stars'}}},
#    {'$match': {'review_count': 1}},
#    {'$group': {'_id': '$_id.business_id',
#      'single_review_user_count': {'$sum': 1},
#      'avg_stars_for_single_reviews': {'$avg': '$avg_stars'}}},
#    {'$lookup': {'from': 'business',
#      'localField': '_id',
#      'foreignField': 'business_id',
#      'as': 'business_details'}},
#    {'$unwind': '$business_details'},
#    {'$project': {'_id': 0,
#      'business_id': '$_id',
#      'business_name': '$business_details.name',
#      'single_review_user_count': 1,
#      'avg_stars_for_single_reviews': {'$round': ['$avg_stars_for_single_reviews',
#        2]}}},
#    {'$sort': {'single_review_user_count': -1}},
#    {'$limit': 3}],
#   'cursor': {},
#   '$db': 'yelp'},
#  'ok': 1.0}

# %% [markdown]
# Simple query

# %%
pipeline = [
    {
        "$match": {
            "city": { "$regex": regex_pattern, "$options": "i" },  
            "state": { "$regex": "^FL$", "$options": "i" },         
            "postal_code": { "$ne": None }                        
        }
    },
    {
        "$group": {
            "_id": "$postal_code",
            "total_businesses": { "$sum": 1 }
        }
    },
    {
        "$sort": { "total_businesses": -1 }
    },
    {
        "$limit": 10
    },
    {
        "$project": {
            "_id": 0,
            "postal_code": "$_id",
            "total_businesses": 1
        }
    }
]


results = business.aggregate(pipeline)
df_top_postal_codes = pd.DataFrame(list(results))
print("Top 10 Postal Codes in Tampa, FL with Most Businesses:")
print(df_top_postal_codes)
# Out:
# Top 10 Postal Codes in Tampa, FL with Most Businesses:
#    total_businesses postal_code
# 0               794       33607
# 1               649       33602
# 2               639       33609
# 3               591       33618
# 4               580       33612
# 5               509       33606
# 6               496       33629
# 7               434       33614
# 8               413       33611
# 9               410       33647

# %%
mydb.command('explain', {'aggregate': 'review', 'pipeline': pipeline, 'cursor': {}}, verbosity='executionStats')
# Out:
# {'explainVersion': '2',
#  'stages': [{'$cursor': {'queryPlanner': {'namespace': 'yelp.review',
#      'parsedQuery': {'$and': [{'city': {'$regex': '^(Tampa|Tampa\\ Bay|tampa|TAMPA)$',
#          '$options': 'i'}},
#        {'state': {'$regex': '^FL$', '$options': 'i'}},
#        {'postal_code': {'$not': {'$eq': None}}}]},
#      'indexFilterSet': False,
#      'queryHash': '452F5FAB',
#      'planCacheKey': '552FAAD7',
#      'optimizationTimeMillis': 0,
#      'maxIndexedOrSolutionsReached': False,
#      'maxIndexedAndSolutionsReached': False,
#      'maxScansToExplodeReached': False,
#      'prunedSimilarIndexes': False,
#      'winningPlan': {'isCached': False,
#       'queryPlan': {'stage': 'GROUP',
#        'planNodeId': 3,
#        'inputStage': {'stage': 'COLLSCAN',
#         'planNodeId': 1,
#         'filter': {'$and': [{'city': {'$regex': '^(Tampa|Tampa\\ Bay|tampa|TAMPA)$',
#             '$options': 'i'}},
#           {'state': {'$regex': '^FL$', '$options': 'i'}},
#           {'postal_code': {'$not': {'$eq': None}}}]},
#         'direction': 'forward'}},
#       'slotBasedPlan': {'slots': '$$RESULT=s14 env: { s6 = /^(Tampa|Tampa\\ Bay|tampa|TAMPA)$/i, s7 = PcreRegex(/^(Tampa|Tampa\\ Bay|tampa|TAMPA)$/i), s8 = /^FL$/i, s9 = PcreRegex(/^FL$/i) }',
#        'stages': '[3] project [s14 = newObj("_id", s11, "total_businesses", s13)] \n[3] project [s13 = (convert ( s12, int32) ?: s12)] \n[3] group [s11] [s12 = count()] spillSlots[s10] mergingExprs[sum(s10)] \n[3] project [s11 = (s1 ?: null)] \n[1] filter {(traverseF(s2, lambda(l4.0) { (((l4.0 == s6) ?: false) || (regexMatch(s7, l4.0) ?: false)) }, false) && (traverseF(s3, lambda(l5.0) { (((l5.0 == s8) ?: false) || (regexMatch(s9, l5.0) ?: false)) }, false) && !(traverseF(s1, lambda(l6.0) { ((\n    if (typeMatch(l6.0, 1024) ?: true) \n    then null \n    else move(l6.0) \n== null) ?: false) }, false))))} \n[1] scan s4 s5 none none none none none none lowPriority [s1 = postal_code, s2 = city, s3 = state] @"31cc9a19-8d68-4c46-b6e2-b7d7d1b37a4d" true false '}},
#      'rejectedPlans': []},
#     'executionStats': {'executionSuccess': True,
#      'nReturned': 0,
#      'executionTimeMillis': 7588,
#      'totalKeysExamined': 0,
#      'totalDocsExamined': 6990277,
#      'executionStages': {'stage': 'project',
#       'planNodeId': 3,
#       'nReturned': 0,
#       'executionTimeMillisEstimate': 7561,
#       'opens': 1,
#       'closes': 1,
#       'saveState': 267,
#       'restoreState': 267,
#       'isEOF': 1,
#       'projections': {'14': 'newObj("_id", s11, "total_businesses", s13) '},
#       'inputStage': {'stage': 'project',
#        'planNodeId': 3,
#        'nReturned': 0,
#        'executionTimeMillisEstimate': 7561,
#        'opens': 1,
#        'closes': 1,
#        'saveState': 267,
#        'restoreState': 267,
#        'isEOF': 1,
#        'projections': {'13': '(convert ( s12, int32) ?: s12) '},
#        'inputStage': {'stage': 'group',
#         'planNodeId': 3,
#         'nReturned': 0,
#         'executionTimeMillisEstimate': 7561,
#         'opens': 1,
#         'closes': 1,
#         'saveState': 267,
#         'restoreState': 267,
#         'isEOF': 1,
#         'groupBySlots': [11],
#         'expressions': {'12': 'count() ', 'initExprs': {'12': None}},
#         'mergingExprs': {'10': 'sum(s10) '},
#         'usedDisk': False,
#         'spills': 0,
#         'spilledBytes': 0,
#         'spilledRecords': 0,
#         'spilledDataStorageSize': 0,
#         'inputStage': {'stage': 'project',
#          'planNodeId': 3,
#          'nReturned': 0,
#          'executionTimeMillisEstimate': 7561,
#          'opens': 1,
#          'closes': 1,
#          'saveState': 267,
#          'restoreState': 267,
#          'isEOF': 1,
#          'projections': {'11': '(s1 ?: null) '},
#          'inputStage': {'stage': 'filter',
#           'planNodeId': 1,
#           'nReturned': 0,
#           'executionTimeMillisEstimate': 7561,
#           'opens': 1,
#           'closes': 1,
#           'saveState': 267,
#           'restoreState': 267,
#           'isEOF': 1,
#           'numTested': 6990277,
#           'filter': '(traverseF(s2, lambda(l4.0) { (((l4.0 == s6) ?: false) || (regexMatch(s7, l4.0) ?: false)) }, false) && (traverseF(s3, lambda(l5.0) { (((l5.0 == s8) ?: false) || (regexMatch(s9, l5.0) ?: false)) }, false) && !(traverseF(s1, lambda(l6.0) { ((\n    if (typeMatch(l6.0, 1024) ?: true) \n    then null \n    else move(l6.0) \n== null) ?: false) }, false)))) ',
#           'inputStage': {'stage': 'scan',
#            'planNodeId': 1,
#            'nReturned': 6990277,
#            'executionTimeMillisEstimate': 6503,
#            'opens': 1,
#            'closes': 1,
#            'saveState': 267,
#            'restoreState': 267,
#            'isEOF': 1,
#            'numReads': 6990277,
#            'recordSlot': 4,
#            'recordIdSlot': 5,
#            'scanFieldNames': ['postal_code', 'city', 'state'],
#            'scanFieldSlots': [1, 2, 3]}}}}}}}},
#    'nReturned': 0,
#    'executionTimeMillisEstimate': 7571},
#   {'$sort': {'sortKey': {'total_businesses': -1}, 'limit': 10},
#    'totalDataSizeSortedBytesEstimate': 0,
#    'usedDisk': False,
#    'spills': 0,
#    'spilledDataStorageSize': 0,
#    'nReturned': 0,
#    'executionTimeMillisEstimate': 7571},
#   {'$project': {'total_businesses': True, 'postal_code': '$_id', '_id': False},
#    'nReturned': 0,
#    'executionTimeMillisEstimate': 7571}],
#  'serverInfo': {'host': 'Riyyas-Laptop.local',
#   'port': 27017,
#   'version': '8.0.1',
#   'gitVersion': 'fcbe67d668fff5a370e2d87b9b1f74bc11bb7b94'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#   'internalQueryFrameworkControl': 'trySbeRestricted',
#   'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1},
#  'command': {'aggregate': 'review',
#   'pipeline': [{'$match': {'city': {'$regex': '^(Tampa|Tampa\\ Bay|tampa|TAMPA)$',
#       '$options': 'i'},
#      'state': {'$regex': '^FL$', '$options': 'i'},
#      'postal_code': {'$ne': None}}},
#    {'$group': {'_id': '$postal_code', 'total_businesses': {'$sum': 1}}},
#    {'$sort': {'total_businesses': -1}},
#    {'$limit': 10},
#    {'$project': {'_id': 0, 'postal_code': '$_id', 'total_businesses': 1}}],
#   'cursor': {},
#   '$db': 'yelp'},
#  'ok': 1.0}

# %%
unique_postal_codes = business.distinct("postal_code", {
        "city": { "$regex": regex_pattern, "$options": "i" },
        "state": { "$regex": "^FL$", "$options": "i" },
        "postal_code": { "$ne": None }
    })
    
distinct_postal_code_count = len(unique_postal_codes)
print(f"Distinct Postal Codes in Tampa Businesses: {distinct_postal_code_count}")
# Out:
# Distinct Postal Codes in Tampa Businesses: 97

# %%
pipeline = [
    {
        "$match": {
            "city": { "$regex": regex_pattern, "$options": "i" },  
            "state": { "$regex": "^FL$", "$options": "i" },         
            "postal_code": { "$ne": None }                        
        }
    },
    {
        "$group": {
            "_id": "$postal_code",
            "total_businesses": { "$sum": 1 }
        }
    },
    {
        "$group": {
            "_id": None,
            "min_businesses": { "$min": "$total_businesses" },
            "max_businesses": { "$max": "$total_businesses" },
            "avg_businesses": { "$avg": "$total_businesses" },
            "stddev_businesses": { "$stdDevSamp": "$total_businesses" }  
        }
    },
    {
        "$project": {
            "_id": 0,
            "min_businesses": 1,
            "max_businesses": 1,
            "avg_businesses": 1,
            "stddev_businesses": 1
        }
    }
]
results = list(business.aggregate(pipeline))
    
df_stats = pd.DataFrame(results)
print("\nBusiness Statistics per Postal Code in Tampa, FL:")
print(df_stats)
# Out:
# Business Statistics per Postal Code in Tampa, FL:
#    min_businesses  max_businesses  avg_businesses  stddev_businesses
# 0               1             794       94.917526         184.141062
